# %%
import pandas as pd
import numpy as np
import datetime
import json

# %%
# URLS = json.loads('citibike_urls.json')

# %%
import requests

url = "http://gbfs.citibikenyc.com/gbfs/gbfs.json"
data_urls = requests.get(url).json()
# data_urls

# %%
# data
posix_stamp = data_urls['last_updated'
last_update = datetime.datetime.fromtimestamp(posix_stamp)
print(f"Last update was: {last_update}")
# Out:
# Last update was: 2020-08-11 18:57:30

# %%
station_status_url =data_urls['data']['en']['feeds'][2]['url']
station_information_url = data_urls['data']['en']['feeds'][1]['url']

# %%
station_information_url

station_information = requests.get(station_information_url).json()
station_information
# Out:
# {'data': {'stations': [{'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6926.01',
#     'lon': -73.99392888,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=72',
#     'region_id': '71',
#     'capacity': 0,
#     'station_id': '72',
#     'name': 'W 52 St & 11 Ave',
#     'legacy_id': '72',
#     'lat': 40.76727216,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db237e-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5430.08',
#     'lon': -74.00666661,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=79',
#     'region_id': '71',
#     'capacity': 33,
#     'station_id': '79',
#     'name': 'Franklin St & W Broadway',
#     'legacy_id': '79',
#     'lat': 40.71911552,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db269c-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5167.06',
#     'lon': -74.00016545,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=82',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '82',
#     'name': 'St James Pl & Pearl St',
#     'legacy_id': '82',
#     'lat': 40.71117416,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db277a-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4354.07',
#     'lon': -73.97632328,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=83',
#     'region_id': '71',
#     'capacity': 62,
#     'station_id': '83',
#     'name': 'Atlantic Ave & Fort Greene Pl',
#     'legacy_id': '83',
#     'lat': 40.68382604,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db281e-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6148.02',
#     'lon': -74.00149746,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=116',
#     'region_id': '71',
#     'capacity': 50,
#     'station_id': '116',
#     'name': 'W 17 St & 8 Ave',
#     'legacy_id': '116',
#     'lat': 40.74177603,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db28b5-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4700.06',
#     'lon': -73.97803415,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=119',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '119',
#     'name': 'Park Ave & St Edwards St',
#     'legacy_id': '119',
#     'lat': 40.69608941,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2953-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4452.03',
#     'lon': -73.95928168,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=120',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '120',
#     'name': 'Lexington Ave & Classon Ave',
#     'legacy_id': '120',
#     'lat': 40.68676793,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db29e6-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5805.05',
#     'lon': -74.00674436,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=127',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '127',
#     'name': 'Barrow St & Hudson St',
#     'legacy_id': '127',
#     'lat': 40.73172428,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2a71-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5687.04',
#     'lon': -74.00297088,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=128',
#     'region_id': '71',
#     'capacity': 30,
#     'station_id': '128',
#     'name': 'MacDougal St & Prince St',
#     'legacy_id': '128',
#     'lat': 40.72710258,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2afe-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4605.04',
#     'lon': -73.99337909,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=143',
#     'region_id': '71',
#     'capacity': 24,
#     'station_id': '143',
#     'name': 'Clinton St & Joralemon St',
#     'legacy_id': '143',
#     'lat': 40.69239502,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2d2b-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4812.02',
#     'lon': -73.98068914,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=144',
#     'region_id': '71',
#     'capacity': 58,
#     'station_id': '144',
#     'name': 'Nassau St & Navy St',
#     'legacy_id': '144',
#     'lat': 40.69839895,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2db5-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5359.10',
#     'lon': -74.0091059,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=146',
#     'region_id': '71',
#     'capacity': 39,
#     'station_id': '146',
#     'name': 'Hudson St & Reade St',
#     'legacy_id': '146',
#     'lat': 40.71625008,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2e3a-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5476.03',
#     'lon': -73.98085795,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=150',
#     'region_id': '71',
#     'capacity': 55,
#     'station_id': '150',
#     'name': 'E 2 St & Avenue C',
#     'legacy_id': '150',
#     'lat': 40.7208736,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2f4c-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5492.05',
#     'lon': -73.99724900722504,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=151',
#     'region_id': '71',
#     'capacity': 33,
#     'station_id': '151',
#     'name': 'Cleveland Pl & Spring St',
#     'legacy_id': '151',
#     'lat': 40.722103786686034,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db2fd0-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4531.05',
#     'lon': -73.99612349,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=157',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '157',
#     'name': 'Henry St & Atlantic Ave',
#     'legacy_id': '157',
#     'lat': 40.69089272,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db316a-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5721.14',
#     'lon': -73.99810231,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=161',
#     'region_id': '71',
#     'capacity': 35,
#     'station_id': '161',
#     'name': 'LaGuardia Pl & W 3 St',
#     'legacy_id': '161',
#     'lat': 40.72917025,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3273-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6498.10',
#     'lon': -73.97032517,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=164',
#     'region_id': '71',
#     'capacity': 47,
#     'station_id': '164',
#     'name': 'E 47 St & 2 Ave',
#     'legacy_id': '164',
#     'lat': 40.75323098,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db32fb-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6389.03',
#     'lon': -73.97604882,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=167',
#     'region_id': '71',
#     'capacity': 45,
#     'station_id': '167',
#     'name': 'E 39 St & 3 Ave',
#     'legacy_id': '167',
#     'lat': 40.7489006,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db337f-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6064.08',
#     'lon': -73.99456405,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=168',
#     'region_id': '71',
#     'capacity': 0,
#     'station_id': '168',
#     'name': 'W 18 St & 6 Ave',
#     'legacy_id': '168',
#     'lat': 40.73971301,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db33fc-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6708.02',
#     'lon': -73.9845272898674,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=173',
#     'region_id': '71',
#     'capacity': 70,
#     'station_id': '173',
#     'name': 'Broadway & W 49 St',
#     'legacy_id': '173',
#     'lat': 40.76068327096592,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db347b-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6004.07',
#     'lon': -73.97738662,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=174',
#     'region_id': '71',
#     'capacity': 30,
#     'station_id': '174',
#     'name': 'E 25 St & 1 Ave',
#     'legacy_id': '174',
#     'lat': 40.7381765,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db34fc-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5105.01',
#     'lon': -74.01043382,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=195',
#     'region_id': '71',
#     'capacity': 45,
#     'station_id': '195',
#     'name': 'Liberty St & Broadway',
#     'legacy_id': '195',
#     'lat': 40.70905623,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3583-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6233.05',
#     'lon': -74.00681753,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=212',
#     'region_id': '71',
#     'capacity': 60,
#     'station_id': '212',
#     'name': 'W 16 St & The High Line',
#     'legacy_id': '212',
#     'lat': 40.74334935,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3606-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4829.01',
#     'lon': -73.99548059,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=216',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '216',
#     'name': 'Columbia Heights & Cranberry St',
#     'legacy_id': '216',
#     'lat': 40.70037867,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3687-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4903.08',
#     'lon': -73.99383605,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=217',
#     'region_id': '71',
#     'capacity': 39,
#     'station_id': '217',
#     'name': 'Old Fulton St',
#     'legacy_id': '217',
#     'lat': 40.70277159,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3708-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6030.04',
#     'lon': -73.99994661,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=223',
#     'region_id': '71',
#     'capacity': 33,
#     'station_id': '223',
#     'name': 'W 13 St & 7 Ave',
#     'legacy_id': '223',
#     'lat': 40.73781509,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3816-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5137.10',
#     'lon': -74.00552427,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=224',
#     'region_id': '71',
#     'capacity': 30,
#     'station_id': '224',
#     'name': 'Spruce St & Nassau St',
#     'legacy_id': '224',
#     'lat': 40.71146364,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3898-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6541.03',
#     'lon': -73.971878855,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=228',
#     'region_id': '71',
#     'capacity': 55,
#     'station_id': '228',
#     'name': 'E 48 St & 3 Ave',
#     'legacy_id': '228',
#     'lat': 40.7546011026,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3997-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5636.11',
#     'lon': -73.99379025,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=229',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '229',
#     'name': 'Great Jones St',
#     'legacy_id': '229',
#     'lat': 40.72743423,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3a1e-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5669.10',
#     'lon': -73.98713956,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=236',
#     'region_id': '71',
#     'capacity': 47,
#     'station_id': '236',
#     'name': 'St Marks Pl & 2 Ave',
#     'legacy_id': '236',
#     'lat': 40.7284186,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3ba0-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5746.04',
#     'lon': -73.98672378,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=237',
#     'region_id': '71',
#     'capacity': 39,
#     'station_id': '237',
#     'name': 'E 11 St & 2 Ave',
#     'legacy_id': '237',
#     'lat': 40.73047309,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3c29-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5964.01',
#     'lon': -74.00859207,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=238',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '238',
#     'name': 'Bank St & Washington St',
#     'legacy_id': '238',
#     'lat': 40.7361967,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3cab-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4628.05',
#     'lon': -73.9813018,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=239',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '239',
#     'name': 'Willoughby St & Fleet St',
#     'legacy_id': '239',
#     'lat': 40.69196566,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3d2a-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4546.04',
#     'lon': -73.97493121,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=241',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '241',
#     'name': 'DeKalb Ave & S Portland Ave',
#     'legacy_id': '241',
#     'lat': 40.68981035,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3da9-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4732.08',
#     'lon': -73.973736,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=242',
#     'region_id': '71',
#     'capacity': 46,
#     'station_id': '242',
#     'name': 'Carlton Ave & Flushing Ave',
#     'legacy_id': '242',
#     'lat': 40.697787,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3e32-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4611.03',
#     'lon': -73.96536851,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=244',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '244',
#     'name': 'Willoughby Ave & Hall St',
#     'legacy_id': '244',
#     'lat': 40.69196035,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3f01-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4659.02',
#     'lon': -73.97703874,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=245',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '245',
#     'name': 'Myrtle Ave & St Edwards St',
#     'legacy_id': '245',
#     'lat': 40.69327018,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3f62-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5922.07',
#     'lon': -74.00483091,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=247',
#     'region_id': '71',
#     'capacity': 55,
#     'station_id': '247',
#     'name': 'Perry St & Bleecker St',
#     'legacy_id': '247',
#     'lat': 40.73535398,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db3fc9-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5539.06',
#     'lon': -74.00771779,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=248',
#     'region_id': '71',
#     'capacity': 99,
#     'station_id': '248',
#     'name': 'Laight St & Hudson St',
#     'legacy_id': '248',
#     'lat': 40.72185379,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db402c-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5400.05',
#     'lon': -74.0090009,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=249',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '249',
#     'name': 'Harrison St & Hudson St',
#     'legacy_id': '249',
#     'lat': 40.71870987,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db408f-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5561.06',
#     'lon': -73.99565293,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=250',
#     'region_id': '71',
#     'capacity': 40,
#     'station_id': '250',
#     'name': 'Lafayette St & Jersey St',
#     'legacy_id': '250',
#     'lat': 40.72456089,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db40ef-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5561.04',
#     'lon': -73.99480012,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=251',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '251',
#     'name': 'Mott St & Prince St',
#     'legacy_id': '251',
#     'lat': 40.72317958,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db4158-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5797.01',
#     'lon': -73.99852205,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=252',
#     'region_id': '71',
#     'capacity': 33,
#     'station_id': '252',
#     'name': 'MacDougal St & Washington Sq',
#     'legacy_id': '252',
#     'lat': 40.73226398,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db41bf-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5914.03',
#     'lon': -73.99800419,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=254',
#     'region_id': '71',
#     'capacity': 47,
#     'station_id': '254',
#     'name': 'W 11 St & 6 Ave',
#     'legacy_id': '254',
#     'lat': 40.73532427,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db4282-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5391.06',
#     'lon': -74.00247214,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=257',
#     'region_id': '71',
#     'capacity': 39,
#     'station_id': '257',
#     'name': 'Lispenard St & Broadway',
#     'legacy_id': '257',
#     'lat': 40.71939226,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db4351-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4461.04',
#     'lon': -73.96885458,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=258',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '258',
#     'name': 'DeKalb Ave & Vanderbilt Ave',
#     'legacy_id': '258',
#     'lat': 40.68940747,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db43b5-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4846.01',
#     'lon': -74.01234218,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=259',
#     'region_id': '71',
#     'capacity': 39,
#     'station_id': '259',
#     'name': 'South St & Whitehall St',
#     'legacy_id': '259',
#     'lat': 40.70122128,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db4417-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4962.08',
#     'lon': -74.01167797,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=260',
#     'region_id': '71',
#     'capacity': 33,
#     'station_id': '260',
#     'name': 'Broad St & Bridge St',
#     'legacy_id': '260',
#     'lat': 40.70365182,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db447a-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4668.08',
#     'lon': -73.98362464,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=261',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '261',
#     'name': 'Johnson St & Gold St',
#     'legacy_id': '261',
#     'lat': 40.69474881,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db44e5-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4546.05',
#     'lon': -73.9737299,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=262',
#     'region_id': '71',
#     'capacity': 24,
#     'station_id': '262',
#     'name': 'Washington Park',
#     'legacy_id': '262',
#     'lat': 40.6917823,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db4549-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5065.10',
#     'lon': -74.00731853,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=264',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '264',
#     'name': 'Maiden Ln & Pearl St',
#     'legacy_id': '264',
#     'lat': 40.70706456,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db460d-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5523.02',
#     'lon': -73.99147535,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=265',
#     'region_id': '71',
#     'capacity': 35,
#     'station_id': '265',
#     'name': 'Stanton St & Chrystie St',
#     'legacy_id': '265',
#     'lat': 40.72229346,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db4671-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6441.01',
#     'lon': -73.98765428,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=267',
#     'region_id': '71',
#     'capacity': 0,
#     'station_id': '267',
#     'name': 'Broadway & W 36 St',
#     'legacy_id': '267',
#     'lat': 40.75097711,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db473c-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5422.04',
#     'lon': -73.99973337,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=268',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '268',
#     'name': 'Howard St & Centre St',
#     'legacy_id': '268',
#     'lat': 40.71910537,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db479e-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4620.02',
#     'lon': -73.97178913,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=270',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '270',
#     'name': 'Adelphi St & Myrtle Ave',
#     'legacy_id': '270',
#     'lat': 40.69308257,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db5c14-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4395.04',
#     'lon': -73.976682,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=274',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '274',
#     'name': 'Lafayette Ave & Fort Greene Pl',
#     'legacy_id': '274',
#     'lat': 40.68691865,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db5d28-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4419.03',
#     'lon': -73.96563307,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=275',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '275',
#     'name': 'Washington Ave & Greene Ave',
#     'legacy_id': '275',
#     'lat': 40.68650065,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db5d92-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5400.08',
#     'lon': -74.0104554,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=276',
#     'region_id': '71',
#     'capacity': 25,
#     'station_id': '276',
#     'name': 'Duane St & Greenwich St',
#     'legacy_id': '276',
#     'lat': 40.71748752,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db5dfb-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4781.03',
#     'lon': -73.98476437,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=278',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '278',
#     'name': 'Concord St & Bridge St',
#     'legacy_id': '278',
#     'lat': 40.69766564,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db5e6a-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5872.08',
#     'lon': -73.99510132,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=280',
#     'region_id': '71',
#     'capacity': 59,
#     'station_id': '280',
#     'name': 'E 10 St & 5 Ave',
#     'legacy_id': '280',
#     'lat': 40.73331967,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db5f40-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6839.10',
#     'lon': -73.97371465,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=281',
#     'region_id': '71',
#     'capacity': 66,
#     'station_id': '281',
#     'name': 'Grand Army Plaza & Central Park S',
#     'legacy_id': '281',
#     'lat': 40.7643971,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db5fae-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5062.01',
#     'lon': -73.96841526031494,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=282',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '282',
#     'name': 'Kent Ave & S 11 St',
#     'legacy_id': '282',
#     'lat': 40.707644944175705,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6299-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6072.06',
#     'lon': -74.0026376103,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=284',
#     'region_id': '71',
#     'capacity': 43,
#     'station_id': '284',
#     'name': 'Greenwich Ave & 8 Ave',
#     'legacy_id': '284',
#     'lat': 40.7390169121,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db631c-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5905.12',
#     'lon': -73.99074142,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=285',
#     'region_id': '71',
#     'capacity': 53,
#     'station_id': '285',
#     'name': 'Broadway & E 14 St',
#     'legacy_id': '285',
#     'lat': 40.73454567,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6387-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4336.01',
#     'lon': -73.95881081,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=289',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '289',
#     'name': 'Monroe St & Classon Ave',
#     'legacy_id': '289',
#     'lat': 40.6845683,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db63f4-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5262.09',
#     'lon': -73.984844,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=291',
#     'region_id': '71',
#     'capacity': 20,
#     'station_id': '291',
#     'name': 'Madison St & Montgomery St',
#     'legacy_id': '291',
#     'lat': 40.713126,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db64d1-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5788.13',
#     'lon': -73.99102628231049,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=293',
#     'region_id': '71',
#     'capacity': 55,
#     'station_id': '293',
#     'name': 'Lafayette St & E 8 St',
#     'legacy_id': '293',
#     'lat': 40.73020660529954,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db65aa-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5270.05',
#     'lon': -73.99293911,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=295',
#     'region_id': '71',
#     'capacity': 24,
#     'station_id': '295',
#     'name': 'Pike St & E Broadway',
#     'legacy_id': '295',
#     'lat': 40.71406667,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6889-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5863.07',
#     'lon': -73.986923,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=297',
#     'region_id': '71',
#     'capacity': 81,
#     'station_id': '297',
#     'name': 'E 15 St & 3 Ave',
#     'legacy_id': '297',
#     'lat': 40.734232,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6963-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4437.01',
#     'lon': -73.9796772,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=298',
#     'region_id': '71',
#     'capacity': 35,
#     'station_id': '298',
#     'name': '3 Ave & Schermerhorn St',
#     'legacy_id': '298',
#     'lat': 40.68683208,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db69d0-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5515.02',
#     'lon': -73.98368779,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=301',
#     'region_id': '71',
#     'capacity': 58,
#     'station_id': '301',
#     'name': 'E 2 St & Avenue B',
#     'legacy_id': '301',
#     'lat': 40.72217444,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6aae-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5436.09',
#     'lon': -73.97793172,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=302',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '302',
#     'name': 'Avenue D & E 3 St',
#     'legacy_id': '302',
#     'lat': 40.72082834,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6cd4-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5532.01',
#     'lon': -73.99949601,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=303',
#     'region_id': '71',
#     'capacity': 67,
#     'station_id': '303',
#     'name': 'Mercer St & Spring St',
#     'legacy_id': '303',
#     'lat': 40.72362738,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6d40-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4962.01',
#     'lon': -74.01361706,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=304',
#     'region_id': '71',
#     'capacity': 33,
#     'station_id': '304',
#     'name': 'Broadway & Battery Pl',
#     'legacy_id': '304',
#     'lat': 40.70463334,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6da2-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': [{'id': '66db6da2-0aca-11e7-82f6-3863bb44ef7c',
#       'off_dock_bikes_count': 19,
#       'docks_availability': 'UNLIMITED',
#       'description': '',
#       'off_dock_remaining_bike_capacity': 51,
#       'service_type': 'ATTENDED_SERVICE',
#       'schedule_description': '',
#       'name': 'Valet Service',
#       'bikes_availability': 'UNLIMITED',
#       'link_for_more_info': ''}]},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '6762.02',
#     'lon': -73.96724467,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=305',
#     'region_id': '71',
#     'capacity': 33,
#     'station_id': '305',
#     'name': 'E 58 St & 3 Ave',
#     'legacy_id': '305',
#     'lat': 40.76095756,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6e49-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5303.08',
#     'lon': -73.98990025,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=307',
#     'region_id': '71',
#     'capacity': 30,
#     'station_id': '307',
#     'name': 'Canal St & Rutgers St',
#     'legacy_id': '307',
#     'lat': 40.71427487,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db6f2e-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5238.05',
#     'lon': -73.99851193,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=308',
#     'region_id': '71',
#     'capacity': 27,
#     'station_id': '308',
#     'name': 'St James Pl & Oliver St',
#     'legacy_id': '308',
#     'lat': 40.71307916,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db7152-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5329.06',
#     'lon': -74.013012,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=309',
#     'region_id': '71',
#     'capacity': 41,
#     'station_id': '309',
#     'name': 'Murray St & West St',
#     'legacy_id': '309',
#     'lat': 40.7149787,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db71be-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4565.06',
#     'lon': -73.98912867,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=310',
#     'region_id': '71',
#     'capacity': 36,
#     'station_id': '310',
#     'name': 'State St & Smith St',
#     'legacy_id': '310',
#     'lat': 40.68926942,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db7221-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5374.01',
#     'lon': -73.98802084,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=311',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '311',
#     'name': 'Norfolk St & Broome St',
#     'legacy_id': '311',
#     'lat': 40.7172274,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db728c-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5484.09',
#     'lon': -73.989111,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=312',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '312',
#     'name': 'Allen St & Stanton St',
#     'legacy_id': '312',
#     'lat': 40.722055,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db72f1-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4724.03',
#     'lon': -73.96751037,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=313',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '313',
#     'name': 'Washington Ave & Park Ave',
#     'legacy_id': '313',
#     'lat': 40.69610226,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db74a5-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': True,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '4953.04',
#     'lon': -74.00670227,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=315',
#     'region_id': '71',
#     'capacity': 29,
#     'station_id': '315',
#     'name': 'South St & Gouverneur Ln',
#     'legacy_id': '315',
#     'lat': 40.70355377,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db75cc-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5137.11',
#     'lon': -74.00653609,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=316',
#     'region_id': '71',
#     'capacity': 43,
#     'station_id': '316',
#     'name': 'Fulton St & William St',
#     'legacy_id': '316',
#     'lat': 40.70955958,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '66db7637-0aca-11e7-82f6-3863bb44ef7c',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '5584.04',
#     'lon': -73.98185424,
# ...
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '7c42f9fc-d280-4841-ad96-e3cc53ee3759',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7976.08',
#     'lon': -73.94386,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3959',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '3959',
#     'name': 'Edgecombe Ave & W 145 St',
#     'legacy_id': '3959',
#     'lat': 40.823498,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '0ddb965d-95ef-4ce3-bde6-81a56ac1fbd2',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7959.18',
#     'lon': -73.951346,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3960',
#     'region_id': '71',
#     'capacity': 21,
#     'station_id': '3960',
#     'name': 'Hamilton Pl & W 140 St',
#     'legacy_id': '3960',
#     'lat': 40.822756,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'c8060816-b4aa-4fd9-bc66-af28bf61dc87',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7901.04',
#     'lon': -73.921411,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3961',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '3961',
#     'name': 'Morris Ave & E 153 St',
#     'legacy_id': '3961',
#     'lat': 40.820036,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '581bc4fe-cf14-4767-8377-6fa156ff8a29',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7879.01',
#     'lon': -73.917338,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3963',
#     'region_id': '71',
#     'capacity': 31,
#     'station_id': '3963',
#     'name': 'Melrose Ave & E 150 St',
#     'legacy_id': '3963',
#     'lat': 40.816827,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '3db799ba-b574-4e5f-95e5-c767bec2acb6',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7816.14',
#     'lon': -73.915368,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3964',
#     'region_id': '71',
#     'capacity': 20,
#     'station_id': '3964',
#     'name': 'Brook Ave & E 148 St',
#     'legacy_id': '3964',
#     'lat': 40.814383,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'b3a9057e-7ff6-4117-b96e-e71c173cf1e9',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7793.02',
#     'lon': -73.91186,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3965',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '3965',
#     'name': 'E 149 St & Eagle Ave',
#     'legacy_id': '3965',
#     'lat': 40.814046,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'e71d152c-c2df-4d3e-a9af-139f2529bac6',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7751.05',
#     'lon': -73.907729,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3966',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '3966',
#     'name': 'Wales Ave & E 147 St',
#     'legacy_id': '3966',
#     'lat': 40.811314,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '0e405c35-322f-4705-8ea7-769eb3fd028a',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '8018.09',
#     'lon': -73.949738,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3967',
#     'region_id': '71',
#     'capacity': 30,
#     'station_id': '3967',
#     'name': 'W 146 St & Broadway',
#     'legacy_id': '3967',
#     'lat': 40.826969,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '1d8e51b0-8131-4c1f-93fb-f04952c157c0',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7830.03',
#     'lon': -73.903927,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3968',
#     'region_id': '71',
#     'capacity': 21,
#     'station_id': '3968',
#     'name': 'Prospect Ave & E 151 St',
#     'legacy_id': '3968',
#     'lat': 40.814232,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '002e6e9f-ced2-47b0-bc7e-ccf38c3b4b0f',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7835.10',
#     'lon': -73.911918,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3969',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '3969',
#     'name': "St Ann's Ave & Westchester Ave",
#     'legacy_id': '3969',
#     'lat': 40.815887,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '40914c6b-293d-49ac-b83a-d9d4af998aea',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7918.12',
#     'lon': -73.916071,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3970',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '3970',
#     'name': 'Melrose Ave & E 154 St',
#     'legacy_id': '3970',
#     'lat': 40.819609,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'e0a9ed84-55f9-40f5-90fa-87db17d2f933',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '8013.07',
#     'lon': -73.942722,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3973',
#     'region_id': '71',
#     'capacity': 26,
#     'station_id': '3973',
#     'name': 'St Nicholas Ave & W 150 St',
#     'legacy_id': '3973',
#     'lat': 40.827212,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '8f1fdf4b-ecca-4f03-b04c-e10fe596e2c7',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7935.07',
#     'lon': -73.911759,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3975',
#     'region_id': '71',
#     'capacity': 21,
#     'station_id': '3975',
#     'name': 'Brook Ave & E 157 St',
#     'legacy_id': '3975',
#     'lat': 40.820713,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '6f21be51-6fde-4cde-b1db-b102a5f67300',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7896.11',
#     'lon': -73.912411,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3976',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '3976',
#     'name': 'E 156 & Brook Ave',
#     'legacy_id': '3976',
#     'lat': 40.819823,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'be435dfd-e859-487c-ae32-3d2b76d49a49',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7870.02',
#     'lon': -73.90202,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3977',
#     'region_id': '71',
#     'capacity': 29,
#     'station_id': '3977',
#     'name': 'Prospect Ave & Longwood Ave',
#     'legacy_id': '3977',
#     'lat': 40.81899,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'df243d7f-e6ae-435c-9895-aecbcff9cada',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7952.02',
#     'lon': -73.907521,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3978',
#     'region_id': '71',
#     'capacity': 18,
#     'station_id': '3978',
#     'name': 'Cauldwell Ave & E 161 St',
#     'legacy_id': '3978',
#     'lat': 40.82188,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '493850bd-125b-49f5-932b-bf999504fb06',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '8069.01',
#     'lon': -73.944279,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3980',
#     'region_id': '71',
#     'capacity': 20,
#     'station_id': '3980',
#     'name': 'Amsterdam Ave & W 152 St',
#     'legacy_id': '3980',
#     'lat': 40.829523,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '85b77b8d-32b8-4049-a407-64319916e2c5',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '8085.13',
#     'lon': -73.939929,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3981',
#     'region_id': '71',
#     'capacity': 24,
#     'station_id': '3981',
#     'name': 'Harlem River Dr & W 155 St',
#     'legacy_id': '3981',
#     'lat': 40.830476,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '676b7b4d-b1c0-4c97-8ac3-5fe665e51108',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7858.02',
#     'lon': -73.914737,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3982',
#     'region_id': '71',
#     'capacity': 21,
#     'station_id': '3982',
#     'name': 'Bergen Ave & E 152 St',
#     'legacy_id': '3982',
#     'lat': 40.817166,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '062f0ac2-b3b6-4c15-b470-92ce9b592635',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7891.06',
#     'lon': -73.905203,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3983',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '3983',
#     'name': 'Westchester Ave & E 156 St',
#     'legacy_id': '3983',
#     'lat': 40.817802,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '517409d3-a94a-4140-a6de-ff0de9221ed2',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7981.27',
#     'lon': -73.954743,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3984',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '3984',
#     'name': 'W 140 St & Riverside Dr',
#     'legacy_id': '3984',
#     'lat': 40.824013,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'fe6f022b-7fdb-44fe-80bb-cbfc500959bf',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7931.05',
#     'lon': -73.903944,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3985',
#     'region_id': '71',
#     'capacity': 22,
#     'station_id': '3985',
#     'name': 'E 160 St & Tinton Ave',
#     'legacy_id': '3985',
#     'lat': 40.820302,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'cda60c6d-80f3-41b7-8ece-fe997f6dafb5',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7863.03',
#     'lon': -73.922962,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3986',
#     'region_id': '71',
#     'capacity': 35,
#     'station_id': '3986',
#     'name': 'E 149 St & Morris Ave',
#     'legacy_id': '3986',
#     'lat': 40.81734,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'd5cb6e67-addb-46d4-93e7-832371736d45',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7812.01',
#     'lon': -73.909235,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3987',
#     'region_id': '71',
#     'capacity': 23,
#     'station_id': '3987',
#     'name': 'E 149 St & Jackson Ave',
#     'legacy_id': '3987',
#     'lat': 40.813135,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'ccfa8b82-07a7-4a08-88fc-be261c30a4ca',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7696.07',
#     'lon': -73.934077,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3988',
#     'region_id': '71',
#     'capacity': 19,
#     'station_id': '3988',
#     'name': 'E 128 St & 3 Ave',
#     'legacy_id': '3988',
#     'lat': 40.805631,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '97bcf094-ad77-4743-9c94-832c7300c090',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7726.02',
#     'lon': -73.923604,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3989',
#     'region_id': '71',
#     'capacity': 22,
#     'station_id': '3989',
#     'name': 'Willis Ave & E 137 St',
#     'legacy_id': '3989',
#     'lat': 40.808384,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'e780c290-0c52-4ab1-9719-a581be789df3',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '8282.13',
#     'lon': -73.9421253,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3992',
#     'region_id': '71',
#     'capacity': 47,
#     'station_id': '3992',
#     'name': 'W 169 St & Fort Washington Ave',
#     'legacy_id': '3992',
#     'lat': 40.8428422,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': '09400a3c-8343-4846-92fe-72fb681e593d',
#     'eightd_station_services': []},
#    {'eightd_has_key_dispenser': False,
#     'rental_methods': ['KEY', 'CREDITCARD'],
#     'electric_bike_surcharge_waiver': False,
#     'short_name': '7648.16',
#     'lon': -73.933509,
#     'rental_url': 'http://app.citibikenyc.com/S6Lr/IBV092JufD?station_id=3994',
#     'region_id': '71',
#     'capacity': 30,
#     'station_id': '3994',
#     'name': '2 Ave & E 125 St',
#     'legacy_id': '3994',
#     'lat': 40.802554,
#     'station_type': 'classic',
#     'has_kiosk': True,
#     'external_id': 'bb07a569-cc74-439e-b424-916c0304f136',
#     'eightd_station_services': []},
#    ...]},
#  'last_updated': 1597186645,
#  'ttl': 5}

# %%
house_latlong = [40.774886, -73.955055]

# %%
closest_dist = 1.0

for station in station_information['data']['stations']:
    dy = station['lat'] - house_latlong[0]
    dx = station['lon'] - house_latlong[1]
    dist = np.sqrt(dy**2+dx**2)
    
    if dist < closest_dist:
        closest_station = station
        closest_dist = dist

# %%
# station_information['data']['stations'][0]

# %%
# closest_station

# %%
station_status['data']['stations']
# Out:
# [{'is_renting': 0,
#   'num_bikes_disabled': 0,
#   'is_installed': 0,
#   'is_returning': 0,
#   'station_status': 'out_of_service',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '72',
#   'legacy_id': '72',
#   'num_docks_disabled': 0,
#   'last_reported': 86400},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 24,
#   'num_docks_available': 8,
#   'eightd_has_available_keys': False,
#   'station_id': '79',
#   'legacy_id': '79',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186112},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 24,
#   'num_docks_available': 3,
#   'eightd_has_available_keys': False,
#   'station_id': '82',
#   'legacy_id': '82',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186337},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 52,
#   'num_docks_available': 10,
#   'eightd_has_available_keys': False,
#   'station_id': '83',
#   'legacy_id': '83',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186636},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 26,
#   'num_docks_available': 23,
#   'eightd_has_available_keys': False,
#   'station_id': '116',
#   'legacy_id': '116',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186640},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 12,
#   'num_docks_available': 7,
#   'eightd_has_available_keys': False,
#   'station_id': '119',
#   'legacy_id': '119',
#   'num_docks_disabled': 0,
#   'last_reported': 1597184982},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 15,
#   'eightd_has_available_keys': False,
#   'station_id': '120',
#   'legacy_id': '120',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186473},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 13,
#   'num_docks_available': 16,
#   'eightd_has_available_keys': False,
#   'station_id': '127',
#   'legacy_id': '127',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186572},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 16,
#   'num_docks_available': 12,
#   'eightd_has_available_keys': False,
#   'station_id': '128',
#   'legacy_id': '128',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186643},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 4,
#   'num_docks_available': 20,
#   'eightd_has_available_keys': False,
#   'station_id': '143',
#   'legacy_id': '143',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185617},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 51,
#   'num_docks_available': 7,
#   'eightd_has_available_keys': False,
#   'station_id': '144',
#   'legacy_id': '144',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185071},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 14,
#   'num_docks_available': 23,
#   'eightd_has_available_keys': False,
#   'station_id': '146',
#   'legacy_id': '146',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186560},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 14,
#   'num_docks_available': 40,
#   'eightd_has_available_keys': False,
#   'station_id': '150',
#   'legacy_id': '150',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186543},
#  {'is_renting': 1,
#   'num_bikes_disabled': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 20,
#   'num_docks_available': 9,
#   'eightd_has_available_keys': False,
#   'station_id': '151',
#   'legacy_id': '151',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186468},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 21,
#   'num_docks_available': 2,
#   'eightd_has_available_keys': False,
#   'station_id': '157',
#   'legacy_id': '157',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186552},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 11,
#   'num_docks_available': 23,
#   'eightd_has_available_keys': False,
#   'station_id': '161',
#   'legacy_id': '161',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186382},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 27,
#   'eightd_has_available_keys': False,
#   'station_id': '164',
#   'legacy_id': '164',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186512},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 43,
#   'eightd_has_available_keys': False,
#   'station_id': '167',
#   'legacy_id': '167',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186565},
#  {'is_renting': 0,
#   'num_bikes_disabled': 0,
#   'is_installed': 0,
#   'is_returning': 0,
#   'station_status': 'out_of_service',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '168',
#   'legacy_id': '168',
#   'num_docks_disabled': 0,
#   'last_reported': 86400},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 68,
#   'eightd_has_available_keys': False,
#   'station_id': '173',
#   'legacy_id': '173',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186562},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 7,
#   'num_docks_available': 23,
#   'eightd_has_available_keys': False,
#   'station_id': '174',
#   'legacy_id': '174',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186202},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 41,
#   'eightd_has_available_keys': False,
#   'station_id': '195',
#   'legacy_id': '195',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186474},
#  {'is_renting': 1,
#   'num_bikes_disabled': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 43,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '212',
#   'legacy_id': '212',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186571},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 9,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '216',
#   'legacy_id': '216',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186454},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 28,
#   'num_docks_available': 10,
#   'eightd_has_available_keys': False,
#   'station_id': '217',
#   'legacy_id': '217',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186071},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 15,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '223',
#   'legacy_id': '223',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185836},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 29,
#   'eightd_has_available_keys': True,
#   'station_id': '224',
#   'legacy_id': '224',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186605},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 22,
#   'num_docks_available': 31,
#   'eightd_has_available_keys': False,
#   'station_id': '228',
#   'legacy_id': '228',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186645},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 23,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '229',
#   'legacy_id': '229',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185874},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 28,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '236',
#   'legacy_id': '236',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186615},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 12,
#   'num_docks_available': 26,
#   'eightd_has_available_keys': False,
#   'station_id': '237',
#   'legacy_id': '237',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186507},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 16,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '238',
#   'legacy_id': '238',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186490},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 20,
#   'num_docks_available': 11,
#   'eightd_has_available_keys': False,
#   'station_id': '239',
#   'legacy_id': '239',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186530},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 22,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '241',
#   'legacy_id': '241',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186628},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 30,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '242',
#   'legacy_id': '242',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186295},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 29,
#   'eightd_has_available_keys': False,
#   'station_id': '244',
#   'legacy_id': '244',
#   'num_docks_disabled': 0,
#   'last_reported': 1597184775},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 12,
#   'num_docks_available': 10,
#   'eightd_has_available_keys': True,
#   'station_id': '245',
#   'legacy_id': '245',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186388},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 36,
#   'eightd_has_available_keys': False,
#   'station_id': '247',
#   'legacy_id': '247',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186617},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 39,
#   'num_docks_available': 60,
#   'eightd_has_available_keys': False,
#   'station_id': '248',
#   'legacy_id': '248',
#   'num_docks_disabled': 0,
#   'last_reported': 1597184567},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '249',
#   'legacy_id': '249',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186512},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 25,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '250',
#   'legacy_id': '250',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186533},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 6,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '251',
#   'legacy_id': '251',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186496},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 22,
#   'num_docks_available': 10,
#   'eightd_has_available_keys': False,
#   'station_id': '252',
#   'legacy_id': '252',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186527},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 37,
#   'eightd_has_available_keys': False,
#   'station_id': '254',
#   'legacy_id': '254',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186512},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 13,
#   'num_docks_available': 24,
#   'eightd_has_available_keys': False,
#   'station_id': '257',
#   'legacy_id': '257',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186438},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 13,
#   'num_docks_available': 10,
#   'eightd_has_available_keys': False,
#   'station_id': '258',
#   'legacy_id': '258',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186588},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 12,
#   'num_docks_available': 24,
#   'eightd_has_available_keys': False,
#   'station_id': '259',
#   'legacy_id': '259',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186630},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 10,
#   'num_docks_available': 23,
#   'eightd_has_available_keys': False,
#   'station_id': '260',
#   'legacy_id': '260',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186345},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 14,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '261',
#   'legacy_id': '261',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185762},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 9,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '262',
#   'legacy_id': '262',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186625},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '264',
#   'legacy_id': '264',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186537},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 30,
#   'num_docks_available': 2,
#   'eightd_has_available_keys': False,
#   'station_id': '265',
#   'legacy_id': '265',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186632},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '267',
#   'legacy_id': '267',
#   'num_docks_disabled': 0,
#   'last_reported': 86400},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 7,
#   'eightd_has_available_keys': False,
#   'station_id': '268',
#   'legacy_id': '268',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186582},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 7,
#   'num_docks_available': 15,
#   'eightd_has_available_keys': False,
#   'station_id': '270',
#   'legacy_id': '270',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186362},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 28,
#   'num_docks_available': 2,
#   'eightd_has_available_keys': False,
#   'station_id': '274',
#   'legacy_id': '274',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186509},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 17,
#   'eightd_has_available_keys': False,
#   'station_id': '275',
#   'legacy_id': '275',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186245},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 10,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '276',
#   'legacy_id': '276',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186548},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 3,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '278',
#   'legacy_id': '278',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186541},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 13,
#   'num_docks_available': 44,
#   'eightd_has_available_keys': False,
#   'station_id': '280',
#   'legacy_id': '280',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186432},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 65,
#   'eightd_has_available_keys': False,
#   'station_id': '281',
#   'legacy_id': '281',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186544},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 10,
#   'num_docks_available': 15,
#   'eightd_has_available_keys': False,
#   'station_id': '282',
#   'legacy_id': '282',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186522},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 26,
#   'num_docks_available': 16,
#   'eightd_has_available_keys': False,
#   'station_id': '284',
#   'legacy_id': '284',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186565},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 7,
#   'num_docks_available': 46,
#   'eightd_has_available_keys': True,
#   'station_id': '285',
#   'legacy_id': '285',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186561},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 19,
#   'eightd_has_available_keys': False,
#   'station_id': '289',
#   'legacy_id': '289',
#   'num_docks_disabled': 0,
#   'last_reported': 1597183154},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 3,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '291',
#   'legacy_id': '291',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186037},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 47,
#   'eightd_has_available_keys': False,
#   'station_id': '293',
#   'legacy_id': '293',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186438},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 13,
#   'num_docks_available': 8,
#   'eightd_has_available_keys': False,
#   'station_id': '295',
#   'legacy_id': '295',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186591},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 26,
#   'num_docks_available': 52,
#   'eightd_has_available_keys': False,
#   'station_id': '297',
#   'legacy_id': '297',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186501},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 28,
#   'num_docks_available': 5,
#   'eightd_has_available_keys': False,
#   'station_id': '298',
#   'legacy_id': '298',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186415},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 50,
#   'eightd_has_available_keys': False,
#   'station_id': '301',
#   'legacy_id': '301',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186533},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 20,
#   'num_docks_available': 3,
#   'eightd_has_available_keys': False,
#   'station_id': '302',
#   'legacy_id': '302',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186627},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 14,
#   'num_docks_available': 51,
#   'eightd_has_available_keys': False,
#   'station_id': '303',
#   'legacy_id': '303',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186577},
#  {'is_renting': 1,
#   'valet': {'off_dock_capacity': 70,
#    'off_dock_count': 19,
#    'dock_blocked_count': 26,
#    'region': 'BKN',
#    'station_id': '66db6da2-0aca-11e7-82f6-3863bb44ef7c',
#    'active': True,
#    'valet_revision': 8439},
#   'num_bikes_disabled': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'eightd_active_station_services': [{'id': '66db6da2-0aca-11e7-82f6-3863bb44ef7c'}],
#   'num_bikes_available': 22,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': True,
#   'station_id': '304',
#   'legacy_id': '304',
#   'num_docks_disabled': 26,
#   'last_reported': 1597186393},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 30,
#   'eightd_has_available_keys': False,
#   'station_id': '305',
#   'legacy_id': '305',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186613},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 24,
#   'num_docks_available': 3,
#   'eightd_has_available_keys': False,
#   'station_id': '307',
#   'legacy_id': '307',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186433},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 24,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '308',
#   'legacy_id': '308',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186289},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 5,
#   'num_docks_available': 36,
#   'eightd_has_available_keys': False,
#   'station_id': '309',
#   'legacy_id': '309',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186158},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 5,
#   'num_docks_available': 31,
#   'eightd_has_available_keys': False,
#   'station_id': '310',
#   'legacy_id': '310',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186310},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 7,
#   'num_docks_available': 22,
#   'eightd_has_available_keys': False,
#   'station_id': '311',
#   'legacy_id': '311',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186583},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 18,
#   'num_docks_available': 11,
#   'eightd_has_available_keys': False,
#   'station_id': '312',
#   'legacy_id': '312',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186639},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 20,
#   'num_docks_available': 3,
#   'eightd_has_available_keys': False,
#   'station_id': '313',
#   'legacy_id': '313',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186504},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 26,
#   'eightd_has_available_keys': True,
#   'station_id': '315',
#   'legacy_id': '315',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186645},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 18,
#   'num_docks_available': 23,
#   'eightd_has_available_keys': False,
#   'station_id': '316',
#   'legacy_id': '316',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186424},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 10,
#   'num_docks_available': 42,
#   'eightd_has_available_keys': False,
#   'station_id': '317',
#   'legacy_id': '317',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186582},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 10,
#   'num_docks_available': 22,
#   'eightd_has_available_keys': False,
#   'station_id': '319',
#   'legacy_id': '319',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186546},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 5,
#   'num_docks_available': 34,
#   'eightd_has_available_keys': False,
#   'station_id': '320',
#   'legacy_id': '320',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186647},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 3,
#   'num_docks_available': 24,
#   'eightd_has_available_keys': False,
#   'station_id': '321',
#   'legacy_id': '321',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186320},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 19,
#   'eightd_has_available_keys': False,
#   'station_id': '323',
#   'legacy_id': '323',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186327},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 45,
#   'num_docks_available': 4,
#   'eightd_has_available_keys': False,
#   'station_id': '324',
#   'legacy_id': '324',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186353},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 3,
#   'num_docks_available': 32,
#   'eightd_has_available_keys': False,
#   'station_id': '325',
#   'legacy_id': '325',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186602},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 7,
#   'num_docks_available': 33,
#   'eightd_has_available_keys': False,
#   'station_id': '326',
#   'legacy_id': '326',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186570},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 14,
#   'num_docks_available': 25,
#   'eightd_has_available_keys': True,
#   'station_id': '327',
#   'legacy_id': '327',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186497},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 13,
#   'num_docks_available': 8,
#   'eightd_has_available_keys': False,
#   'station_id': '328',
#   'legacy_id': '328',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186419},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 7,
#   'num_docks_available': 31,
#   'eightd_has_available_keys': False,
#   'station_id': '330',
#   'legacy_id': '330',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186189},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 17,
#   'eightd_has_available_keys': False,
#   'station_id': '331',
#   'legacy_id': '331',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186566},
#  {'is_renting': 1,
#   'num_bikes_disabled': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 17,
#   'num_docks_available': 15,
#   'eightd_has_available_keys': False,
#   'station_id': '332',
#   'legacy_id': '332',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186641},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 16,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '334',
#   'legacy_id': '334',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186592},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 26,
#   'eightd_has_available_keys': False,
#   'station_id': '335',
#   'legacy_id': '335',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186600},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 21,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '336',
#   'legacy_id': '336',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186593},
#  {'is_renting': 0,
#   'num_bikes_disabled': 0,
#   'is_installed': 0,
#   'is_returning': 0,
#   'station_status': 'out_of_service',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '339',
#   'legacy_id': '339',
#   'num_docks_disabled': 0,
#   'last_reported': 86400},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 11,
#   'num_docks_available': 15,
#   'eightd_has_available_keys': True,
#   'station_id': '340',
#   'legacy_id': '340',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186646},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 15,
#   'num_docks_available': 4,
#   'eightd_has_available_keys': False,
#   'station_id': '341',
#   'legacy_id': '341',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186638},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 27,
#   'num_docks_available': 1,
#   'eightd_has_available_keys': False,
#   'station_id': '342',
#   'legacy_id': '342',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186486},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 2,
#   'eightd_has_available_keys': False,
#   'station_id': '343',
#   'legacy_id': '343',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185811},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 23,
#   'eightd_has_available_keys': False,
#   'station_id': '344',
#   'legacy_id': '344',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185374},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 21,
#   'num_docks_available': 5,
#   'eightd_has_available_keys': False,
#   'station_id': '346',
#   'legacy_id': '346',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186640},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 22,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '347',
#   'legacy_id': '347',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186619},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 26,
#   'num_docks_available': 35,
#   'eightd_has_available_keys': False,
#   'station_id': '349',
#   'legacy_id': '349',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186629},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 15,
#   'num_docks_available': 12,
#   'eightd_has_available_keys': False,
#   'station_id': '350',
#   'legacy_id': '350',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186592},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 20,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '351',
#   'legacy_id': '351',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186641},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 5,
#   'eightd_has_available_keys': False,
#   'station_id': '353',
#   'legacy_id': '353',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186528},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 39,
#   'eightd_has_available_keys': False,
#   'station_id': '354',
#   'legacy_id': '354',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186115},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 30,
#   'num_docks_available': 11,
#   'eightd_has_available_keys': False,
#   'station_id': '355',
#   'legacy_id': '355',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186201},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '356',
#   'legacy_id': '356',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186375},
#  {'is_renting': 1,
#   'valet': {'off_dock_capacity': 70,
#    'off_dock_count': 0,
#    'dock_blocked_count': 45,
#    'region': 'BKN',
#    'station_id': '66dbc8f5-0aca-11e7-82f6-3863bb44ef7c',
#    'active': True,
#    'valet_revision': 575},
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'eightd_active_station_services': [{'id': '66dbc8f5-0aca-11e7-82f6-3863bb44ef7c'}],
#   'num_bikes_available': 47,
#   'num_docks_available': 0,
#   'eightd_has_available_keys': False,
#   'station_id': '358',
#   'legacy_id': '358',
#   'num_docks_disabled': 45,
#   'last_reported': 1597186611},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 76,
#   'eightd_has_available_keys': False,
#   'station_id': '359',
#   'legacy_id': '359',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186629},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 35,
#   'eightd_has_available_keys': False,
#   'station_id': '360',
#   'legacy_id': '360',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186497},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 33,
#   'num_docks_available': 9,
#   'eightd_has_available_keys': False,
#   'station_id': '361',
#   'legacy_id': '361',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186485},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 5,
#   'num_docks_available': 51,
#   'eightd_has_available_keys': False,
#   'station_id': '362',
#   'legacy_id': '362',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186618},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 23,
#   'num_docks_available': 26,
#   'eightd_has_available_keys': False,
#   'station_id': '363',
#   'legacy_id': '363',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186592},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 25,
#   'eightd_has_available_keys': False,
#   'station_id': '364',
#   'legacy_id': '364',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186477},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 5,
#   'num_docks_available': 28,
#   'eightd_has_available_keys': False,
#   'station_id': '366',
#   'legacy_id': '366',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186242},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 31,
#   'eightd_has_available_keys': False,
#   'station_id': '367',
#   'legacy_id': '367',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185954},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 22,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': True,
#   'station_id': '368',
#   'legacy_id': '368',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186541},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 2,
#   'num_bikes_available': 21,
#   'num_docks_available': 39,
#   'eightd_has_available_keys': False,
#   'station_id': '369',
#   'legacy_id': '369',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186546},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 17,
#   'num_docks_available': 10,
#   'eightd_has_available_keys': False,
#   'station_id': '372',
#   'legacy_id': '372',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186336},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 16,
#   'num_docks_available': 2,
#   'eightd_has_available_keys': False,
#   'station_id': '373',
#   'legacy_id': '373',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186137},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 25,
#   'num_docks_available': 16,
#   'eightd_has_available_keys': False,
#   'station_id': '376',
#   'legacy_id': '376',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186592},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 30,
#   'num_docks_available': 17,
#   'eightd_has_available_keys': False,
#   'station_id': '377',
#   'legacy_id': '377',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186488},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 37,
#   'num_docks_available': 3,
#   'eightd_has_available_keys': False,
#   'station_id': '379',
#   'legacy_id': '379',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186566},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 38,
#   'num_docks_available': 1,
#   'eightd_has_available_keys': False,
#   'station_id': '380',
#   'legacy_id': '380',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186581},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 20,
#   'eightd_has_available_keys': False,
#   'station_id': '383',
#   'legacy_id': '383',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186637},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 5,
#   'num_docks_available': 22,
#   'eightd_has_available_keys': False,
#   'station_id': '385',
#   'legacy_id': '385',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186607},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 22,
#   'num_docks_available': 57,
#   'eightd_has_available_keys': False,
#   'station_id': '386',
#   'legacy_id': '386',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186368},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 38,
#   'eightd_has_available_keys': True,
#   'station_id': '387',
#   'legacy_id': '387',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186593},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 3,
#   'num_docks_available': 31,
#   'eightd_has_available_keys': False,
#   'station_id': '388',
#   'legacy_id': '388',
# ...
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3939',
#   'legacy_id': '3939',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186078},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 15,
#   'num_docks_available': 1,
#   'eightd_has_available_keys': False,
#   'station_id': '3940',
#   'legacy_id': '3940',
#   'num_docks_disabled': 0,
#   'last_reported': 1597163082},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 10,
#   'num_docks_available': 7,
#   'eightd_has_available_keys': False,
#   'station_id': '3941',
#   'legacy_id': '3941',
#   'num_docks_disabled': 0,
#   'last_reported': 1597180079},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 17,
#   'num_docks_available': 4,
#   'eightd_has_available_keys': False,
#   'station_id': '3942',
#   'legacy_id': '3942',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186537},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 30,
#   'eightd_has_available_keys': False,
#   'station_id': '3944',
#   'legacy_id': '3944',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185079},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 16,
#   'num_docks_available': 5,
#   'eightd_has_available_keys': False,
#   'station_id': '3945',
#   'legacy_id': '3945',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185969},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 12,
#   'eightd_has_available_keys': False,
#   'station_id': '3946',
#   'legacy_id': '3946',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185978},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 17,
#   'eightd_has_available_keys': False,
#   'station_id': '3947',
#   'legacy_id': '3947',
#   'num_docks_disabled': 0,
#   'last_reported': 1597182534},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 22,
#   'eightd_has_available_keys': False,
#   'station_id': '3948',
#   'legacy_id': '3948',
#   'num_docks_disabled': 0,
#   'last_reported': 1597180743},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 22,
#   'num_docks_available': 1,
#   'eightd_has_available_keys': False,
#   'station_id': '3949',
#   'legacy_id': '3949',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186282},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 14,
#   'num_docks_available': 5,
#   'eightd_has_available_keys': False,
#   'station_id': '3950',
#   'legacy_id': '3950',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185628},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 6,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3951',
#   'legacy_id': '3951',
#   'num_docks_disabled': 0,
#   'last_reported': 1597183835},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 11,
#   'eightd_has_available_keys': False,
#   'station_id': '3952',
#   'legacy_id': '3952',
#   'num_docks_disabled': 0,
#   'last_reported': 1597180991},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 9,
#   'num_docks_available': 16,
#   'eightd_has_available_keys': False,
#   'station_id': '3953',
#   'legacy_id': '3953',
#   'num_docks_disabled': 0,
#   'last_reported': 1597184607},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 6,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3955',
#   'legacy_id': '3955',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185840},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 12,
#   'num_docks_available': 11,
#   'eightd_has_available_keys': False,
#   'station_id': '3956',
#   'legacy_id': '3956',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185846},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 4,
#   'num_docks_available': 15,
#   'eightd_has_available_keys': False,
#   'station_id': '3957',
#   'legacy_id': '3957',
#   'num_docks_disabled': 0,
#   'last_reported': 1597181375},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 10,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3958',
#   'legacy_id': '3958',
#   'num_docks_disabled': 0,
#   'last_reported': 1597181511},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 4,
#   'num_docks_available': 25,
#   'eightd_has_available_keys': False,
#   'station_id': '3959',
#   'legacy_id': '3959',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186603},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 19,
#   'eightd_has_available_keys': False,
#   'station_id': '3960',
#   'legacy_id': '3960',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185219},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 6,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3961',
#   'legacy_id': '3961',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186590},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 29,
#   'eightd_has_available_keys': False,
#   'station_id': '3963',
#   'legacy_id': '3963',
#   'num_docks_disabled': 0,
#   'last_reported': 1597179787},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '3964',
#   'legacy_id': '3964',
#   'num_docks_disabled': 0,
#   'last_reported': 1597182830},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 17,
#   'eightd_has_available_keys': False,
#   'station_id': '3965',
#   'legacy_id': '3965',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185444},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 17,
#   'eightd_has_available_keys': False,
#   'station_id': '3966',
#   'legacy_id': '3966',
#   'num_docks_disabled': 0,
#   'last_reported': 1597184723},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 19,
#   'num_docks_available': 11,
#   'eightd_has_available_keys': False,
#   'station_id': '3967',
#   'legacy_id': '3967',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186392},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 5,
#   'num_docks_available': 16,
#   'eightd_has_available_keys': False,
#   'station_id': '3968',
#   'legacy_id': '3968',
#   'num_docks_disabled': 0,
#   'last_reported': 1597180451},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '3969',
#   'legacy_id': '3969',
#   'num_docks_disabled': 0,
#   'last_reported': 1597151459},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 15,
#   'num_docks_available': 4,
#   'eightd_has_available_keys': False,
#   'station_id': '3970',
#   'legacy_id': '3970',
#   'num_docks_disabled': 0,
#   'last_reported': 1597181490},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 24,
#   'eightd_has_available_keys': False,
#   'station_id': '3973',
#   'legacy_id': '3973',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186425},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 8,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3975',
#   'legacy_id': '3975',
#   'num_docks_disabled': 0,
#   'last_reported': 1597183215},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 6,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3976',
#   'legacy_id': '3976',
#   'num_docks_disabled': 0,
#   'last_reported': 1597176308},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 28,
#   'eightd_has_available_keys': False,
#   'station_id': '3977',
#   'legacy_id': '3977',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185703},
#  {'is_renting': 1,
#   'num_bikes_disabled': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 13,
#   'num_docks_available': 2,
#   'eightd_has_available_keys': False,
#   'station_id': '3978',
#   'legacy_id': '3978',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185785},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 3,
#   'num_docks_available': 15,
#   'eightd_has_available_keys': False,
#   'station_id': '3980',
#   'legacy_id': '3980',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185894},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 24,
#   'eightd_has_available_keys': False,
#   'station_id': '3981',
#   'legacy_id': '3981',
#   'num_docks_disabled': 0,
#   'last_reported': 1597185611},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 18,
#   'num_docks_available': 2,
#   'eightd_has_available_keys': False,
#   'station_id': '3982',
#   'legacy_id': '3982',
#   'num_docks_disabled': 0,
#   'last_reported': 1597181366},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 1,
#   'num_docks_available': 22,
#   'eightd_has_available_keys': False,
#   'station_id': '3983',
#   'legacy_id': '3983',
#   'num_docks_disabled': 0,
#   'last_reported': 1597176812},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 2,
#   'num_docks_available': 16,
#   'eightd_has_available_keys': False,
#   'station_id': '3984',
#   'legacy_id': '3984',
#   'num_docks_disabled': 4,
#   'last_reported': 1597186484},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 2,
#   'num_bikes_available': 4,
#   'num_docks_available': 18,
#   'eightd_has_available_keys': False,
#   'station_id': '3985',
#   'legacy_id': '3985',
#   'num_docks_disabled': 0,
#   'last_reported': 1597182091},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 1,
#   'num_bikes_available': 17,
#   'num_docks_available': 16,
#   'eightd_has_available_keys': False,
#   'station_id': '3986',
#   'legacy_id': '3986',
#   'num_docks_disabled': 0,
#   'last_reported': 1597184496},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 9,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '3987',
#   'legacy_id': '3987',
#   'num_docks_disabled': 0,
#   'last_reported': 1597184766},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 5,
#   'num_docks_available': 14,
#   'eightd_has_available_keys': False,
#   'station_id': '3988',
#   'legacy_id': '3988',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186441},
#  {'is_renting': 1,
#   'num_bikes_disabled': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 17,
#   'num_docks_available': 4,
#   'eightd_has_available_keys': False,
#   'station_id': '3989',
#   'legacy_id': '3989',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186271},
#  {'is_renting': 1,
#   'num_bikes_disabled': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 0,
#   'num_docks_available': 45,
#   'eightd_has_available_keys': False,
#   'station_id': '3992',
#   'legacy_id': '3992',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186606},
#  {'is_renting': 1,
#   'num_bikes_disabled': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'station_status': 'active',
#   'num_ebikes_available': 0,
#   'num_bikes_available': 17,
#   'num_docks_available': 13,
#   'eightd_has_available_keys': False,
#   'station_id': '3994',
#   'legacy_id': '3994',
#   'num_docks_disabled': 0,
#   'last_reported': 1597186478},
#  ...]

# %%
station_status = requests.get(station_status_url).json()

# %%
for station in station_status['data']['stations']:
#     print(station['station_id'])
    if station['station_id'] == '3671':
        print(station)
# Out:
# {'is_renting': 1, 'num_bikes_disabled': 1, 'is_installed': 1, 'is_returning': 1, 'station_status': 'active', 'num_ebikes_available': 0, 'num_bikes_available': 3, 'num_docks_available': 33, 'eightd_has_available_keys': False, 'station_id': '3671', 'legacy_id': '3671', 'num_docks_disabled': 0, 'last_reported': 1597186472}

# %%
import time


# dictlist = station_status['data']['stations']

# home_station = next(item for item in dictlist if item['station_id'] == "3671")
# last_time = home_station['last_reported']
last_time = 0 

# num_bikes = []
bike_data = []
for i in range(100):
    station_status = requests.get(station_status_url).json() 
    dictlist = station_status['data']['stations']
    home_station = next(item for item in dictlist if item['station_id'] == "3671")
    
    if home_station['last_reported'] != last_time: 
        last_time = home_station['last_reported']
#         bike_data = [last_time, home_station['num_bikes_available']]
        bike_data.append([last_time, home_station['num_bikes_available']])
        print(bike_data)
    time.sleep(10)
    print(i, last_time)
#     print(bike_data)
# Out:
# [[1597188484, 6]]
# 0 1597188484
# 1 1597188484
# 2 1597188484
# 3 1597188484
# 4 1597188484
# 5 1597188484
# 6 1597188484
# 7 1597188484
# 8 1597188484
# 9 1597188484
# 10 1597188484
# 11 1597188484
# 12 1597188484
# 13 1597188484
# 14 1597188484
# 15 1597188484
# 16 1597188484
# 17 1597188484
# 18 1597188484
# 19 1597188484
# 20 1597188484
# 21 1597188484
# 22 1597188484
# 23 1597188484
# 24 1597188484
# 25 1597188484
# 26 1597188484
# 27 1597188484
# 28 1597188484
# 29 1597188484
# 30 1597188484
# 31 1597188484
# 32 1597188484
# 33 1597188484
# 34 1597188484
# 35 1597188484
# 36 1597188484
# 37 1597188484
# 38 1597188484
# 39 1597188484
# 40 1597188484
# 41 1597188484
# 42 1597188484
# 43 1597188484
# 44 1597188484
# 45 1597188484
# [[1597188484, 6], [1597189002, 6]]
# 46 1597189002
# 47 1597189002
# [[1597188484, 6], [1597189002, 6], [1597189006, 6]]
# 48 1597189006
# 49 1597189006
# 50 1597189006
# 51 1597189006
# 52 1597189006
# 53 1597189006
# 54 1597189006
# 55 1597189006
# 56 1597189006
# 57 1597189006
# 58 1597189006
# 59 1597189006
# 60 1597189006
# 61 1597189006
# 62 1597189006
# 63 1597189006
# [[1597188484, 6], [1597189002, 6], [1597189006, 6], [1597189184, 6]]
# 64 1597189184
# 65 1597189184
# 66 1597189184
# [[1597188484, 6], [1597189002, 6], [1597189006, 6], [1597189184, 6], [1597189205, 5]]
# 67 1597189205
# 68 1597189205
# [[1597188484, 6], [1597189002, 6], [1597189006, 6], [1597189184, 6], [1597189205, 5], [1597189224, 6]]
# 69 1597189224
# [[1597188484, 6], [1597189002, 6], [1597189006, 6], [1597189184, 6], [1597189205, 5], [1597189224, 6], [1597189241, 5]]
# 70 1597189241
# 71 1597189241
# 72 1597189241
# 73 1597189241
# 74 1597189241
# 75 1597189241
# 76 1597189241
# 77 1597189241
# 78 1597189241
# 79 1597189241
# 80 1597189241
# 81 1597189241
# [[1597188484, 6], [1597189002, 6], [1597189006, 6], [1597189184, 6], [1597189205, 5], [1597189224, 6], [1597189241, 5], [1597189335, 5]]
# 82 1597189335
# 83 1597189335
# 84 1597189335
# 85 1597189335
# 86 1597189335
# 87 1597189335
# 88 1597189335
# 89 1597189335
# [[1597188484, 6], [1597189002, 6], [1597189006, 6], [1597189184, 6], [1597189205, 5], [1597189224, 6], [1597189241, 5], [1597189335, 5], [1597189430, 6]]
# 90 1597189430
# 91 1597189430
# 92 1597189430
# 93 1597189430
# 94 1597189430
# 95 1597189430
# 96 1597189430
# 97 1597189430
# 98 1597189430
# 99 1597189430

# %%
bike_data
# Out:
# [[1597188484, 6],
#  [1597189002, 6],
#  [1597189006, 6],
#  [1597189184, 6],
#  [1597189205, 5],
#  [1597189224, 6],
#  [1597189241, 5],
#  [1597189335, 5],
#  [1597189430, 6]]
